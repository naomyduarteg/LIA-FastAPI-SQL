# %%
import pandas as pd
import numpy as np
from numpy import dot
from numpy.linalg import norm 

df = pd.read_csv(r'd:\naomy\LIA-FastAPI-MySQL\data\data.csv')
df.head()
# Out:
#    id                      title                  author  \
# 0   1            Matadouro cinco           Kurt Vonnegut
# 1   2               Cama de gato           Kurt Vonnegut
# 2   3        Cem anos de solidão  Gabriel Garcia Marquez
# 3   4        Cem anos de solidão  Gabriel Garcia Marquez
# 4   5  Sobre os ossos dos mortos         Olga Tockarzuck
#
#                                          description            genre  \
# 0  Um livro que zomba da estupidez humana com um ...  Science Fiction
# 1  Mais um livro incrível que zomba da condição h...  Science Fiction
# 2           Um realismo fantástico lindo e cativante    Fiction Novel
# 3                                                NaN    Fiction Novel
# 4  Uma história sobre nossa relação com a naturez...    Fiction Novel
#
#    classification  pages  owner_id
# 0               5    288         1
# 1               5    280         1
# 2               5    448         1
# 3               5    448         2
# 4               5    256         1

# %%
df_init = df.copy()
df_init.head()
# Out:
#    id                      title                  author  \
# 0   1            Matadouro cinco           Kurt Vonnegut
# 1   2               Cama de gato           Kurt Vonnegut
# 2   3        Cem anos de solidão  Gabriel Garcia Marquez
# 3   4        Cem anos de solidão  Gabriel Garcia Marquez
# 4   5  Sobre os ossos dos mortos         Olga Tockarzuck
#
#                                          description            genre  \
# 0  Um livro que zomba da estupidez humana com um ...  Science Fiction
# 1  Mais um livro incrível que zomba da condição h...  Science Fiction
# 2           Um realismo fantástico lindo e cativante    Fiction Novel
# 3                                                NaN    Fiction Novel
# 4  Uma história sobre nossa relação com a naturez...    Fiction Novel
#
#    classification  pages  owner_id
# 0               5    288         1
# 1               5    280         1
# 2               5    448         1
# 3               5    448         2
# 4               5    256         1

# %%
df.rename(columns={'id':'book_id'},inplace=True)
df.head()
# Out:
#    book_id                      title                  author  \
# 0        1            Matadouro cinco           Kurt Vonnegut
# 1        2               Cama de gato           Kurt Vonnegut
# 2        3        Cem anos de solidão  Gabriel Garcia Marquez
# 3        4        Cem anos de solidão  Gabriel Garcia Marquez
# 4        5  Sobre os ossos dos mortos         Olga Tockarzuck
#
#                                          description            genre  \
# 0  Um livro que zomba da estupidez humana com um ...  Science Fiction
# 1  Mais um livro incrível que zomba da condição h...  Science Fiction
# 2           Um realismo fantástico lindo e cativante    Fiction Novel
# 3                                                NaN    Fiction Novel
# 4  Uma história sobre nossa relação com a naturez...    Fiction Novel
#
#    classification  pages  owner_id
# 0               5    288         1
# 1               5    280         1
# 2               5    448         1
# 3               5    448         2
# 4               5    256         1

# %%
def normalize(data):
    '''
    Normalize input data to be between 0 and 1
    
    params:
        data: values you want to normalize
    
    returns:
        The input data normalized between 0 and 1
    '''
    min_val = min(data)
    if min_val < 0:
        data = [x + abs(min_val) for x in data]
    max_val = max(data)
    return [x/max_val for x in data]

# %%
df['pages_norm'] = normalize(df['pages'].values)
df['book_rating_norm'] = normalize(df['classification'].values)

# %%
def ohe(df, enc_col):
    '''
    This function will one hot encode the specified column and add it back
    onto the input dataframe
    
    params:
        df (DataFrame) : The dataframe you wish for the results to be appended to
        enc_col (String) : The column you want to OHE
    
    returns:
        The OHE columns added onto the input dataframe
    '''
    
    ohe_df = pd.get_dummies(df[enc_col])
    ohe_df.reset_index(drop = True, inplace = True)
    return pd.concat([df, ohe_df], axis = 1)

# %%
df = ohe(df = df, enc_col = 'genre')
df = ohe(df = df, enc_col = 'author')

# %%
cols = ['pages', 'genre', 'description', 'title', 'author']
df.drop(columns = cols, inplace = True)
df.set_index('book_id', inplace = True)

# %%
class CBRecommend():
    def __init__(self, df):
        self.df = df
        
    def cosine_sim(self, v1,v2):
        '''
        This function will calculate the cosine similarity between two vectors
        '''
        return dot(v1,v2)/(norm(v1)*norm(v2))
    
    def recommend(self, book_id, n_rec, owner_id):
        """
        df (dataframe): The dataframe
        song_id (string): Representing the song name
        n_rec (int): amount of rec user wants
        """
        
        # calculate similarity of input book_id vector and all other vectors
        inputVec = self.df.loc[book_id].values
        self.df['sim']= self.df.apply(lambda x: self.cosine_sim(inputVec,x.values), axis=1)
        
        df_rec = self.df.nlargest(columns='sim',n=n_rec)
        df_final = df_rec.loc[df['owner_id'] != owner_id]
        # returns top n user specified books that the user didnt listed already
        return df_final

# %%
t = df.copy()
cbr = CBRecommend(df = t)

df_recommendations = cbr.recommend(book_id = t.index[3], n_rec = 10, owner_id = 3)
df_recommendations
# Out:
#          classification  owner_id  pages_norm  book_rating_norm  Dystopian  \
# book_id
# 4                     5         2    0.277743               1.0          0
# 78                    5         2    0.099194               1.0          0
# 3                     5         1    0.277743               1.0          0
# 107                   5         2    0.297582               1.0          0
# 84                    5         2    0.130192               1.0          0
# 98                    4         2    0.228146               0.8          0
# 27                    5         1    0.322381               1.0          0
# 41                    5         1    0.228146               1.0          0
#
#          Fantasy, Adventure  Fiction Novel  Graphic Novel  \
# book_id
# 4                         0              1              0
# 78                        0              1              0
# 3                         0              1              0
# 107                       0              1              0
# 84                        0              1              0
# 98                        0              1              0
# 27                        0              1              0
# 41                        0              1              0
#
#          Mystery, Suspense, Horror  Nonfiction  ...  Stephenie Meyer  \
# book_id                                         ...
# 4                                0           0  ...                0
# 78                               0           0  ...                0
# 3                                0           0  ...                0
# 107                              0           0  ...                0
# 84                               0           0  ...                0
# 98                               0           0  ...                0
# 27                               0           0  ...                0
# 41                               0           0  ...                0
#
#          Ted Chiang  Tess Gerritsen   Ursula K LeGuin  Ursula LeGuin  \
# book_id
# 4                 0                0                0              0
# 78                0                0                0              0
# 3                 0                0                0              0
# 107               0                0                0              0
# 84                0                0                0              0
# 98                0                0                0              0
# 27                0                0                0              0
# 41                0                0                0              0
#
#          Victor Bonini  Victor LaValle  William Peter Blatty  \
# book_id
# 4                    0               0                     0
# 78                   0               0                     0
# 3                    0               0                     0
# 107                  0               0                     0
# 84                   0               0                     0
# 98                   0               0                     0
# 27                   0               0                     0
# 41                   0               0                     0
#
#          William Shakespeare       sim
# book_id
# 4                          0  1.000000
# 78                         0  0.999503
# 3                          0  0.984834
# 107                        0  0.968825
# 84                         0  0.968457
# 98                         0  0.958629
# 27                         0  0.952058
# 41                         0  0.952050
#
# [8 rows x 89 columns]

# %%
df_recommendations.index.values
# Out:
# array([  4,  78,   3, 107,  84,  98,  27,  41], dtype=int64)

# %%
df_seila= df_init.loc[df_init['id'].isin(df_recommendations.index.values), ['title']]
df_seila.drop_duplicates(inplace=True)
#gets only the titles and the ids of the books recommended
df_seila.to_dict(orient='list')
# Out:
# {'title': ['Cem anos de solidão',
#   'Americanah',
#   'Memórias póstumas de Brás Cubas',
#   'Crônicas de uma morte anunciada',
#   'Tudo é rio',
#   'As ruínas',
#   'A menina que roubava livros']}
